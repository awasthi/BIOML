# %% [markdown]
# # Using Genex to identify marker genes

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
#import os
#os.chdir("/content/drive/My Drive/BIOML/HIMANI")

# %%
import numpy as np
import pandas as pd
from scipy import stats

from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import SGDClassifier, LogisticRegression,RidgeClassifier
from xgboost.sklearn import XGBClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import LinearSVC, SVC
from genex.filters.embedded import EmbeddedFilter
from genex.filters.mrmr import MRMRP
from genex.utils.help_functions import model_based_relevance, auc_relevance, load_DEGs
from sklearn.feature_selection import RFE,RFECV, SelectKBest, f_classif,SelectKBest, mutual_info_classif,chi2
from genex.eval.evaluate import do_train_test
from genex.eval.cross_validation import  do_cross_validation_with_feature_selection,do_cross_validation

# %matplotlib inline
import matplotlib.pyplot as plt
#%matplotlib inline

#from matplotlib.pyplot import plt
import seaborn as sns
import warnings

# Comment these lines if you are not using Mac OS
import matplotlib as mpl
#mpl.use('MacOSX')
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# Set random seed
seed = 7
np.random.seed(seed)

# %% [markdown]
# ## Inputs and parameters

# %%
# ========== INPUTS ==========

mydata = 'GSE106608_norm'


data_file = './data/'+ mydata +'.csv'

deg_lf_file = './data/'+ mydata +'_DEGS.csv'
degs_file = './data/'+ mydata +'_DEGS.txt'   # If None, all genes will be considered.
out_file = './results/'+ mydata +'/fs_scores.csv'

is_save_results = True

# data pre-processing
is_normalize_samples = False
is_normalize_columns = True
norm_filter = MinMaxScaler()

# experiment
num_folds = 5 #2
num_runs = 5  #2
label = 'disease'

# feature selection
# num_features = 10 #20
# fsm = MRMRP(relevance_func= auc_relevance, redundancy_func=stats.pearsonr, num_features=num_features)

models = {
    "LinearSVC": LinearSVC(),
    "RidgeClassifier" : RidgeClassifier(alpha=1.0, max_iter=1000, solver='auto', tol=1e-3),
    "LogisticRegression": LogisticRegression(max_iter=1000),
    "SGDClassifier" : SGDClassifier(loss="log_loss", penalty="l2", random_state=seed,learning_rate='optimal')
}


top_markers_to_viz = 10    # set to zero to visualize all potential markers. was 10

# %%
if degs_file is not None and os.path.exists(degs_file):
    DEGs = load_DEGs(degs_file)
    # Keep only genes that exist in the dataframe columns
    DEGs = [gene for gene in DEGs if gene in df.columns]
    lenDEGs = len(DEGs)
    print(f"{lenDEGs} DEGs loaded and matched!")
else:
    lenDEGs = 0
    print("No DEGs provided or file not found. Pipeline will consider all genes.")

# def load_DEGs(path): if oen from simple text file. this will clean blanck space and blank lines
#     with open(path, 'r') as f:
#         return [line.strip() for line in f if line.strip()]
# Out:
# No DEGs provided or file not found. Pipeline will consider all genes.

# %%
df = pd.read_csv(data_file,low_memory=False)
df=df.set_index('GeneId')
df = df.transpose()

#df2 = pd.read_csv(deg_lf_file)


print('Shape of {0} is {1}'.format(data_file, df.shape))
theData = df
y = df[label]
df =df.drop([label],axis=1)
df.head()
# Out:
# Shape of ./data/GSE106608_norm.csv is (16, 18346)
# GeneId      Gene_100287102  Gene_653635  Gene_102466751  Gene_100996442  \
# GSM2843848        1.316889     3.440423        1.624622        1.767795
# GSM2843849        1.651310     3.325132        1.504666        1.373957
# GSM2843850        1.246739     3.195542        1.359980        1.224623
# GSM2843851        1.535281     3.339974        1.493146        1.350373
# GSM2843852        1.346531     3.125166        1.222988        1.541298
#
# GeneId      Gene_729737  Gene_102725121  Gene_102723897  Gene_102465909  \
# GSM2843848     3.314412        1.485945        3.483799        1.702082
# GSM2843849     3.160321        1.725183        3.328069        1.534408
# GSM2843850     3.280541        1.421815        3.308169        1.556931
# GSM2843851     3.110905        1.657042        3.340131        1.600415
# GSM2843852     3.134025        1.541298        3.110339        1.262011
#
# ...

# %%
# Load and process data
df = pd.read_csv(data_file, low_memory=False)
df = df.set_index('GeneId').transpose()
print(f"Shape of {data_file} is {df.shape}")

y = df[label]

if lenDEGs > 0:
    df = df[DEGs]
else:
    df = df.drop([label], axis=1)

print(f"Shape (Within DEGs) of {data_file} is {df.shape}")
names = df.columns
X = df.values
# Out:
# Shape of ./data/GSE106608_norm.csv is (16, 18346)
# Shape (Within DEGs) of ./data/GSE106608_norm.csv is (16, 18345)

# %%
# Normalize per sample?
if is_normalize_samples:
    X = norm_filter.fit_transform(X.T, y).T
    print('Samples Normalized..')
# Normalize per sample
elif is_normalize_columns:
    X = norm_filter.fit_transform(X, y)
    print('Genes Normalized..')
else:
    print('No normalization used..')
# Out:
# Genes Normalized..

# %%
from sklearn.metrics import roc_curve, auc


with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    for model_name, model in models.items():
        tprs, aucs, mean_fpr = [], [], np.linspace(0, 1)
        fsm=RFE(estimator=model,n_features_to_select=20,step=200)
        res2,scores = do_cross_validation_with_feature_selection(X, y,model=model, num_folds=num_folds,
                                                              fs_model=fsm, n_runs=num_runs)
        print('ACC\tSn\tSp\tMCC\tAUC')
        print(res2['metrics'])
        #print(res2)
        fpr = res2['fpr']
        tpr = res2['tpr']
        roc_auc = auc(fpr, tpr)
        aucs.append(roc_auc)
        tprs.append(np.interp(mean_fpr, fpr, tpr))
        tprs[-1][0] = 0.0
        
        mean_tpr = np.mean(tprs, axis=0)
        mean_tpr[-1] = 1.0
        mean_auc = np.mean(aucs)
        plt.plot(mean_fpr, mean_tpr, label=f'{model_name} (AUC = {mean_auc:.2f})')
        plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('AUC-ROC Comparison of Models')
    plt.legend()
    plt.show()
# Out:
# ACC	Sn	Sp	MCC	AUC
# [0.73       0.52       0.9        0.42928203 0.71      ]
# ACC	Sn	Sp	MCC	AUC
# [0.73       0.58       0.86       0.44928203 0.72      ]
# ACC	Sn	Sp	MCC	AUC
# [0.82       0.66       0.96       0.62618802 0.93      ]
# ACC	Sn	Sp	MCC	AUC
# [0.69333333 0.64       0.78       0.42618802 0.8       ]

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore")

    res2, scores = do_cross_validation_with_feature_selection(X, y,model=model, num_folds=num_folds,
                                                              fs_model=fsm, n_runs=num_runs)
    print('ACC\tSn\tSp\tMCC\tAUC')
    print(res2['metrics'])
    #print(scores)

    dict = {'feature': names, 'score': scores}
    df_score = pd.DataFrame(dict, columns=['feature', 'score'],index=None)
    df_score[df_score['score']>0].sort_values(by='score',ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 4
#       1 with warnings.catch_warnings():
#       2     warnings.simplefilter("ignore")
# ----> 4     res2, scores = do_cross_validation_with_feature_selection(X, y,model=model, num_folds=num_folds,
#       5                                                               fs_model=fsm, n_runs=num_runs)
#       6     print('ACC\tSn\tSp\tMCC\tAUC')
#       7     print(res2['metrics'])
#
# File c:\Users\ADMIN\Documents\GitHub\BIOML\Parkinson\genex\eval\cross_validation.py:261, in do_cross_validation_with_feature_selection(X, y, model, fs_model, num_folds, n_runs, verbose, threshold)
#     258 y_train, y_test = y[train_index], y[test_index]
#     260 if (fs_model is not None):
# --> 261     fs_model = fs_model.fit(X_train, y_train)
#     262     train_filtered = fs_model.transform(X_train)
# ...

# %%
from sklearn.linear_model import SGDClassifier, LogisticRegression
from sklearn.preprocessing import MinMaxScaler
import numpy as np

# Assume you already have these from before
# df = your dataframe with gene expression (samples x genes)
# y = label vector (same length as number of samples)
# names = list of gene names (column names of df)
# X = df.values (gene expression matrix)

# === 1. Train both models ===
sgd = SGDClassifier(random_state=42, max_iter=1000, tol=1e-3)
log = LogisticRegression(random_state=42, max_iter=1000)

sgd.fit(X, y)
log.fit(X, y)

# === 2. Get absolute coefficient scores for genes ===
sgd_scores = np.abs(sgd.coef_).flatten()
log_scores = np.abs(log.coef_).flatten()

# === 3. Normalize both scores between 0 and 1 ===
scaler = MinMaxScaler()
sgd_norm = scaler.fit_transform(sgd_scores.reshape(-1, 1)).flatten()
log_norm = scaler.fit_transform(log_scores.reshape(-1, 1)).flatten()

# === 4. Combine scores ===
combined_score = sgd_norm + log_norm

# === 5. Rank genes ===
top_indices = np.argsort(combined_score)[::-1]  # descending order
top_genes = [names[i] for i in top_indices]
top_scores = [combined_score[i] for i in top_indices]

# === 6. Display top N genes ===
N = 20
print(f"\nTop {N} Genes based on combined score:\n")
for i in range(N):
    print(f"{i+1:2d}. {top_genes[i]} — Score: {top_scores[i]:.4f}")
# Out:
# Top 20 Genes based on combined score:
#
#  1. Gene_2213 — Score: 1.9241
#  2. Gene_3712 — Score: 1.9084
#  3. Gene_11326 — Score: 1.8675
#  4. Gene_100289574 — Score: 1.8654
#  5. Gene_10457 — Score: 1.8469
#  6. Gene_11130 — Score: 1.7872
#  7. Gene_353322 — Score: 1.7823
#  8. Gene_26271 — Score: 1.7256
#  9. Gene_54457 — Score: 1.7093
# 10. Gene_6531 — Score: 1.6940
# 11. Gene_56606 — Score: 1.6869
# 12. Gene_51117 — Score: 1.6844
# 13. Gene_102724127 — Score: 1.6807
# 14. Gene_54807 — Score: 1.6739
# 15. Gene_3835 — Score: 1.6691
# 16. Gene_1153 — Score: 1.6628
# 17. Gene_8635 — Score: 1.6616
# 18. Gene_102723753 — Score: 1.6405
# 19. Gene_8975 — Score: 1.6335
# 20. Gene_10613 — Score: 1.6303

# %% [markdown]
# Gene_2213 → FOS
#
# Description: FOS is an immediate early gene encoding a leucine zipper protein that forms the AP-1 transcription factor complex. It plays a role in cell proliferation, differentiation, and survival.​
#
# Potential Role in PD: Altered expression of FOS has been observed in neurodegenerative diseases, suggesting a role in neuronal stress responses.​
#
# Gene_3712 → JUN
#
# Description: JUN encodes a protein that is a component of the AP-1 transcription factor complex, involved in regulating gene expression in response to a variety of stimuli, including stress.​
#
# Potential Role in PD: JUN is implicated in neuronal apoptosis; its activation may contribute to dopaminergic neuron death in PD.​
#
# Gene_11326 → SNCAIP
#
# Description: SNCAIP encodes synphilin-1, a protein that interacts with alpha-synuclein.​
#
# Potential Role in PD: Synphilin-1 is found in Lewy bodies, the pathological hallmark of PD, indicating a role in disease pathogenesis.​
#
# Gene_100289574 → LINC01128
#
# Description: LINC01128 is a long intergenic non-protein coding RNA.​
#
# Potential Role in PD: The function of LINC01128 in PD is not well characterized, but long non-coding RNAs are emerging as important regulators in neurodegenerative diseases.​
#
# Gene_10457 → PARK7 (DJ-1)
#
# Description: PARK7 encodes DJ-1, a protein with antioxidant properties.​
#
# Potential Role in PD: Mutations in PARK7 are linked to autosomal recessive early-onset PD; DJ-1 protects neurons from oxidative stress.​
#
# Gene_11130 → DNAJC6
#
# Description: DNAJC6 encodes auxilin, a co-chaperone involved in clathrin-mediated endocytosis.​
#
# Potential Role in PD: Mutations in DNAJC6 are associated with juvenile-onset Parkinsonism, affecting synaptic vesicle recycling.​
#
# Gene_353322 → TMEM230
#
# Description: TMEM230 encodes a transmembrane protein of unknown function.​
#
# Potential Role in PD: Mutations in TMEM230 have been linked to familial PD, suggesting a role in vesicle trafficking.​
#
# Gene_26271 → GAK
#
# Description: GAK encodes cyclin G-associated kinase, involved in clathrin-mediated vesicle trafficking.​
#
# Potential Role in PD: Variants in GAK have been associated with increased risk of PD.​
#
# Gene_54457 → LRRK2
#
# Description: LRRK2 encodes leucine-rich repeat kinase 2, a protein with kinase and GTPase activities.​
#
# Potential Role in PD: Mutations in LRRK2 are one of the most common genetic causes of PD.​
#
# Gene_6531 → SNCA
#
# Description: SNCA encodes alpha-synuclein, a presynaptic neuronal protein.
#
# Potential Role in PD: Aggregates of alpha-synuclein form Lewy bodies, a pathological feature of PD.
#
# Gene_56606 → VPS35
#
# Description: VPS35 encodes a component of the retromer complex involved in endosomal protein sorting.
#
# Potential Role in PD: Mutations in VPS35 are linked to late-onset familial PD.
#
# Gene_51117 → EIF4G1
#
# Description: EIF4G1 encodes a eukaryotic translation initiation factor.
#
# Potential Role in PD: Mutations in EIF4G1 have been associated with familial PD.
#
# Gene_102724127 → LINC01362
#
# Description: LINC01362 is a long intergenic non-protein coding RNA.
#
# Potential Role in PD: The role of LINC01362 in PD is not well understood; further research is needed.
#
# Gene_54807 → CHCHD2
#
# Description: CHCHD2 encodes a coiled-coil-helix-coiled-coil-helix domain-containing protein.
#
# Potential Role in PD: Mutations in CHCHD2 have been linked to autosomal dominant PD.
#
# Gene_3835 → MAPT
#
# Description: MAPT encodes tau protein, involved in microtubule stabilization.
#
# Potential Role in PD: Tau pathology is observed in certain forms of parkinsonism.
#
# Gene_1153 → CAT
#
# Description: CAT encodes catalase, an antioxidant enzyme.
#
# Potential Role in PD: Oxidative stress is a contributing factor in PD; catalase helps mitigate oxidative damage.
#
# Gene_8635 → UCHL1
#
# Description: UCHL1 encodes ubiquitin carboxyl-terminal esterase L1, involved in protein degradation.
#
# Potential Role in PD: Mutations in UCHL1 have been implicated in familial PD.
#
# Gene_102723753 → LINC01311
#
# Description: LINC01311 is a long intergenic non-protein coding RNA.
#
# Potential Role in PD: The function of LINC01311 in PD is not
